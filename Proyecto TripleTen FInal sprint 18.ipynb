# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # **PROYECTO FINAL**

# %% [markdown]
# ##  **OBJETIVO DEL PROYECTO**
#
# Realizar un analisis de por que los clientes se estan llendo de la empresa de telefonia, implementar logaritmos de maching learning e hiperparametros para ver la forma de mejorar la estancia de los clientes con la empresa y mejorar propuestas para los clientes que tienen ya varios años de fidelidad, asi como evitar la fuga de los clientes.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Buen trabajo organizando tu proyecto y mostrando compromiso con la entrega. Sin embargo, es importante tener en cuenta la estructura que debe seguir este ejercicio. Te explico a continuación de manera clara cómo están divididas las entregas:
#
# * **Parte 1: Plan de Trabajo**
#   Esta sección corresponde únicamente al diseño del plan y fue la que se revisó anteriormente.
#
# * **Parte 2: Código de Solución**
#   En esta parte debes incluir únicamente el desarrollo del código con tus tablas y visualizaciones. **Esta es la sección que corresponde revisar ahora.**
#
# * **Parte 3: Informe Final**
#   Esta es la sección donde se incluye la redacción con conclusiones, propuesta de valor y reflexiones finales. **Esta parte se revisará en la siguiente entrega.**
#
# 💡 **Recuerda:** Cada una de estas tres partes se entrega por separado. En esta ocasión, has subido todo el proyecto en una sola entrega, lo cual no es el formato correcto.
#
#
#
# </div>

# %% [markdown]
# ## **1.- INICIALIZACION**

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import os
import matplotlib.pyplot as plt
import seaborn as sns
import inspect
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## **2.- CARGA Y LIMPIAZA DE DATOS**

# %%
# Carga de archivos 
contract = pd.read_csv("contract.csv", index_col=0)
internet = pd.read_csv("internet.csv", index_col=0)
personal = pd.read_csv("personal.csv", index_col=0)
phone = pd.read_csv("phone.csv", index_col=0)

# %% [markdown]
# ##### **LIMPIEZA DEL DF CONTRACT**

# %%
# visualizar los DataFrame contract
contract.head()
# Out:
#              BeginDate              EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG  2020-01-01                   No  Month-to-month              Yes
# 5575-GNVDE  2017-04-01                   No        One year               No
# 3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month              Yes
# 7795-CFOCW  2016-05-01                   No        One year               No
# 9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month              Yes
#
#                         PaymentMethod  MonthlyCharges TotalCharges
# customerID
# 7590-VHVEG           Electronic check           29.85        29.85
# 5575-GNVDE               Mailed check           56.95       1889.5
# 3668-QPYBK               Mailed check           53.85       108.15
# 7795-CFOCW  Bank transfer (automatic)           42.30      1840.75
# 9237-HQITU           Electronic check           70.70       151.65

# %%
# Info de DataFrame contract
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   object
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 440.2+ KB

# %%
# Info de DataFrame contract
contract.describe()
# Out:
#        MonthlyCharges
# count     7043.000000
# mean        64.761692
# std         30.090047
# min         18.250000
# 25%         35.500000
# 50%         70.350000
# 75%         89.850000
# max        118.750000

# %%
# Transformar datos de tipo obj a de tipo datatime
contract["BeginDate"] = pd.to_datetime(contract["BeginDate"])
contract
# Out:
#             BeginDate              EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01                   No  Month-to-month              Yes
# 5575-GNVDE 2017-04-01                   No        One year               No
# 3668-QPYBK 2019-10-01  2019-12-01 00:00:00  Month-to-month              Yes
# 7795-CFOCW 2016-05-01                   No        One year               No
# 9237-HQITU 2019-09-01  2019-11-01 00:00:00  Month-to-month              Yes
# ...               ...                  ...             ...              ...
# 6840-RESVB 2018-02-01                   No        One year              Yes
# 2234-XADUH 2014-02-01                   No        One year              Yes
# 4801-JZAZL 2019-03-01                   No  Month-to-month              Yes
# 8361-LTMKD 2019-07-01  2019-11-01 00:00:00  Month-to-month              Yes
# 3186-AJIEK 2014-08-01                   No        Two year              Yes
#
# ...

# %%
# Convertir el tipo de datos de EndDate en formato de tiempo
contract["EndDate"] = pd.to_datetime(contract["EndDate"], errors='coerce')
contract.head()
# Out:
#             BeginDate    EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01        NaT  Month-to-month              Yes
# 5575-GNVDE 2017-04-01        NaT        One year               No
# 3668-QPYBK 2019-10-01 2019-12-01  Month-to-month              Yes
# 7795-CFOCW 2016-05-01        NaT        One year               No
# 9237-HQITU 2019-09-01 2019-11-01  Month-to-month              Yes
#
#                         PaymentMethod  MonthlyCharges TotalCharges
# customerID
# 7590-VHVEG           Electronic check           29.85        29.85
# 5575-GNVDE               Mailed check           56.95       1889.5
# 3668-QPYBK               Mailed check           53.85       108.15
# 7795-CFOCW  Bank transfer (automatic)           42.30      1840.75
# 9237-HQITU           Electronic check           70.70       151.65

# %%
#Convertir la columna TotalChanges a valores de tipo float
contract["TotalCharges"] = pd.to_numeric(contract["TotalCharges"], errors="coerce")

# Llenar Valores nulos de TotalCharges
contract["TotalCharges"] = contract["TotalCharges"].fillna(0)

# Convertit a tipo de dato float
contract["TotalCharges"] = contract["TotalCharges"].astype("float64")

# Convertir columnas de texto a minúsculas
contract = contract.apply(lambda col: col.str.lower() if col.dtype == "object" else col)
contract.head()
# Out:
#             BeginDate    EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01        NaT  month-to-month              yes
# 5575-GNVDE 2017-04-01        NaT        one year               no
# 3668-QPYBK 2019-10-01 2019-12-01  month-to-month              yes
# 7795-CFOCW 2016-05-01        NaT        one year               no
# 9237-HQITU 2019-09-01 2019-11-01  month-to-month              yes
#
#                         PaymentMethod  MonthlyCharges  TotalCharges
# customerID
# 7590-VHVEG           electronic check           29.85         29.85
# 5575-GNVDE               mailed check           56.95       1889.50
# 3668-QPYBK               mailed check           53.85        108.15
# 7795-CFOCW  bank transfer (automatic)           42.30       1840.75
# 9237-HQITU           electronic check           70.70        151.65

# %%
# Verificar que los datos esten en el formato correcto
contract.dtypes
# Out:
# BeginDate           datetime64[ns]
# EndDate             datetime64[ns]
# Type                        object
# PaperlessBilling            object
# PaymentMethod               object
# MonthlyCharges             float64
# TotalCharges               float64
# dtype: object

# %%
# Ver los datos unicos de la columna enddate
sorted(contract["EndDate"].unique())
# Out:
# [numpy.datetime64('NaT'),
#  numpy.datetime64('2019-10-01T00:00:00.000000000'),
#  numpy.datetime64('2019-11-01T00:00:00.000000000'),
#  numpy.datetime64('2019-12-01T00:00:00.000000000'),
#  numpy.datetime64('2020-01-01T00:00:00.000000000')]

# %%
# Contar lo datos unicos de la columna EndDate
contract["EndDate"].nunique()
# Out:
# 4

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Excelente trabajo en la integración y limpieza de datos. Lograste unir correctamente los diferentes DataFrames mediante el customerID, aplicando transformaciones tipográficas coherentes y resolviendo de manera efectiva los valores nulos, especialmente en columnas clave como TotalCharges y EndDate. Este tipo de procesamiento riguroso es esencial para la robustez del modelo final.
#
# </div>

# %%
#Visualizacion de los datos del df contract
g = sns.pairplot(contract, kind='hist')
g.fig.set_size_inches(8, 8)

# %%
# Convertir fechas a días desde la fecha mínima
contract["EndDate"] = pd.to_datetime(contract["EndDate"], errors='coerce')

dias_desde_min = (contract["EndDate"] - contract["EndDate"].min()).dt.days

#Grafica de bigotes de los datos dias minimos y ver el rango
plt.figure(figsize=(8, 2))
sns.boxplot(x=dias_desde_min, color="yellow")
plt.title("Caja de bigotes de días desde la fecha mínima de fin de contrato")
plt.xlabel("Días desde fecha mínima")
plt.grid(True)
plt.show()

# %%
contract.hist(bins=50, figsize=(12,12))
plt.show()

# %% [markdown]
# #### **Con los graficos del df contract vemos diferentes parametros de como se comportan los datos con las diferentes columnas. Todo esto lo realizamos por que la variable objetivo sera EndDate, ya que es la fecha en cuando los clientes salieron.**

# %% [markdown]
# ##### **LIMPIEZA DEL DF INTERNET**

# %%
# Ver el df internet
internet.head()
# Out:
#            InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# customerID
# 7590-VHVEG             DSL             No          Yes               No
# 5575-GNVDE             DSL            Yes           No              Yes
# 3668-QPYBK             DSL            Yes          Yes               No
# 7795-CFOCW             DSL            Yes           No              Yes
# 9237-HQITU     Fiber optic             No           No               No
#
#            TechSupport StreamingTV StreamingMovies
# customerID
# 7590-VHVEG          No          No              No
# 5575-GNVDE          No          No              No
# 3668-QPYBK          No          No              No
# 7795-CFOCW         Yes          No              No
# 9237-HQITU          No          No              No

# %%
#Informacion del df internet
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5517 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   5517 non-null   object
#  1   OnlineSecurity    5517 non-null   object
#  2   OnlineBackup      5517 non-null   object
#  3   DeviceProtection  5517 non-null   object
#  4   TechSupport       5517 non-null   object
#  5   StreamingTV       5517 non-null   object
#  6   StreamingMovies   5517 non-null   object
# dtypes: object(7)
# memory usage: 344.8+ KB

# %%
# Descripcion del df internet
internet.describe()
# Out:
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             5517           5517         5517             5517
# unique               2              2            2                2
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies
# count         5517        5517            5517
# unique           2           2               2
# top             No          No              No
# freq          3473        2810            2785

# %%
# Convertir en minusculas df internet
internet = internet.apply(lambda col: col.str.lower() if col.dtypes == "object" else col)
# Convertir índice a minúsculas si es texto
if internet.index.dtype == 'object':
    internet.index = internet.index.str.lower()

# %%
# Verificar valores nulos
internet.isnull().sum()
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %%
# Ver transformacion del df
internet.head(3)
# Out:
#            InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# customerID
# 7590-vhveg             dsl             no          yes               no
# 5575-gnvde             dsl            yes           no              yes
# 3668-qpybk             dsl            yes          yes               no
#
#            TechSupport StreamingTV StreamingMovies
# customerID
# 7590-vhveg          no          no              no
# 5575-gnvde          no          no              no
# 3668-qpybk          no          no              no

# %% [markdown]
# ##### **LIMPIEZA DEL DF PERSONAL**

# %%
# Visualizar el df personal
personal.head()
# Out:
#             gender  SeniorCitizen Partner Dependents
# customerID
# 7590-VHVEG  Female              0     Yes         No
# 5575-GNVDE    Male              0      No         No
# 3668-QPYBK    Male              0      No         No
# 7795-CFOCW    Male              0      No         No
# 9237-HQITU  Female              0      No         No

# %%
#Informacion del df personal
personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7043 non-null   object
#  1   SeniorCitizen  7043 non-null   int64
#  2   Partner        7043 non-null   object
#  3   Dependents     7043 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 275.1+ KB

# %%
# Convertir en minusculas df personal
personal = personal.apply(lambda col: col.str.lower() if col.dtypes == "object" else col)

# %%
#Verificar cuantos valores tiene la columna SeniorCitizen
personal["SeniorCitizen"].unique()
# Out:
# array([0, 1])

# %%
#Verificar cuantos valores tiene la columna Partner
personal["Partner"].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
#Verificar cuantos valores tiene la columna Dependents
personal["Dependents"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %% [markdown]
# ##### **LIMPIEZA DEL DF PHONE**

# %%
# Visualizacion del df phone
phone.head()
# Out:
#            MultipleLines
# customerID
# 5575-GNVDE            No
# 3668-QPYBK            No
# 9237-HQITU            No
# 9305-CDSKC           Yes
# 1452-KIOVK           Yes

# %%
# Info del df phone
phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6361 entries, 5575-GNVDE to 3186-AJIEK
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MultipleLines  6361 non-null   object
# dtypes: object(1)
# memory usage: 99.4+ KB

# %%
# Descripcion del df phone
phone.describe()
# Out:
#        MultipleLines
# count           6361
# unique             2
# top               No
# freq            3390

# %%
# Convertir en minusculas df internet
phone = phone.apply(lambda col: col.str.lower() if col.dtypes == "object" else col)

# %%
# Valores nulos del df phone
phone.isnull().sum()
# Out:
# MultipleLines    0
# dtype: int64

# %% [markdown]
# #### **Ya se tienen los datos limpios y vamos a proceder a unir los cuatro D.F. en uno solo, los cuatro tienen en comun la columna de id por lo que utilizaremos esto para su concatenacion, asi mismo es mas practico analizar ya solo un D.F.**

# %% [markdown]
# ## **3.- EDA**

# %% [markdown]
# #### **NOTA: Anomalía en la columna EndDate como:**
#
# *Hay valores "No" y también fechas reales (2019-12-01 00:00:00).
#
# *Es probable que "No" signifique que el contrato aún está activo.
#
# *Por lo que utilizaremos el metodo churn para crear una columna nueva con 0 y 1 para tener los valores numericos de la gente que esta activa y la que no.

# %%
# Crear variable objetivo: churn = 1 si EndDate no es NaT, es decir, el cliente abandonó
contract['churn'] = contract['EndDate'].notna().astype(int)
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   datetime64[ns]
#  1   EndDate           1869 non-null   datetime64[ns]
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   float64
#  7   churn             7043 non-null   int64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(3)
# memory usage: 495.2+ KB

# %% [markdown]
# #### **Con la aplicacion de churn tenemos:**
#
# churn = 1: el cliente ya no está activo (tiene una EndDate)
#
# churn = 0: el cliente sigue activo (EndDate es NaT)

# %%
# Verificar que se creara la columna churn para verificar que los clientes esten con 0 y 1 
contract.head(5)
# Out:
#             BeginDate    EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01        NaT  month-to-month              yes
# 5575-GNVDE 2017-04-01        NaT        one year               no
# 3668-QPYBK 2019-10-01 2019-12-01  month-to-month              yes
# 7795-CFOCW 2016-05-01        NaT        one year               no
# 9237-HQITU 2019-09-01 2019-11-01  month-to-month              yes
#
#                         PaymentMethod  MonthlyCharges  TotalCharges  churn
# customerID
# 7590-VHVEG           electronic check           29.85         29.85      0
# 5575-GNVDE               mailed check           56.95       1889.50      0
# 3668-QPYBK               mailed check           53.85        108.15      1
# 7795-CFOCW  bank transfer (automatic)           42.30       1840.75      0
# 9237-HQITU           electronic check           70.70        151.65      1

# %% [markdown]
# #### Ya con la columna churn del D.F. contract procederemos a realizar la concatenacion de los cuatro D.F. para crear uno solo llamado Df conplete.

# %%
df_complete_inner = pd.concat([contract, internet, personal, phone], join= "inner", axis=1)
df_complete_inner.head()
# Out:
# Empty DataFrame
# Columns: [BeginDate, EndDate, Type, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, churn, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, gender, SeniorCitizen, Partner, Dependents, MultipleLines]
# Index: []

# %%
# Verificar los customer que se eliminaron con el inner 
print("Tamaño original:", contract.shape[0])
print("Tamaño después del merge:", df_complete_inner.shape[0])
# Out:
# Tamaño original: 7043
# Tamaño después del merge: 0

# %% [markdown]
# #### Se eliminaron 2208 clientes por lo que se cambiara la forma de unir los df de **"INNER" a "OUTER"**

# %%
#Unir los df con outer
df_complete_outer = pd.concat([contract, internet, personal, phone], join= "outer", axis=1)
df_complete_outer.head()
# Out:
#             BeginDate    EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01        NaT  month-to-month              yes
# 5575-GNVDE 2017-04-01        NaT        one year               no
# 3668-QPYBK 2019-10-01 2019-12-01  month-to-month              yes
# 7795-CFOCW 2016-05-01        NaT        one year               no
# 9237-HQITU 2019-09-01 2019-11-01  month-to-month              yes
#
#                         PaymentMethod  MonthlyCharges  TotalCharges  churn  \
# customerID
# 7590-VHVEG           electronic check           29.85         29.85    0.0
# 5575-GNVDE               mailed check           56.95       1889.50    0.0
# 3668-QPYBK               mailed check           53.85        108.15    1.0
# 7795-CFOCW  bank transfer (automatic)           42.30       1840.75    0.0
# 9237-HQITU           electronic check           70.70        151.65    1.0
#
#            InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# customerID
# ...

# %%
# Verificar los customer que se eliminaron con el inner 
print("Tamaño original:", contract.shape[0])
print("Tamaño después del merge:", df_complete_outer.shape[0])
# Out:
# Tamaño original: 7043
# Tamaño después del merge: 12560

# %%
# Verificar valores nulos o faltantes del df completo
df_complete_outer.isna().sum().sort_values(ascending=False)
# Out:
# EndDate             10691
# OnlineBackup         7043
# InternetService      7043
# StreamingMovies      7043
# StreamingTV          7043
# TechSupport          7043
# DeviceProtection     7043
# OnlineSecurity       7043
# MultipleLines        6199
# churn                5517
# TotalCharges         5517
# MonthlyCharges       5517
# PaymentMethod        5517
# PaperlessBilling     5517
# Type                 5517
# gender               5517
# SeniorCitizen        5517
# Partner              5517
# Dependents           5517
# BeginDate            5517
# dtype: int64

# %%
# Eliminamos la columna End Date y BeginDate
df_complete_outer.drop(columns=["EndDate", "BeginDate"], inplace=True)
df_complete_outer.head()
# Out:
#                       Type PaperlessBilling              PaymentMethod  \
# customerID
# 7590-VHVEG  month-to-month              yes           electronic check
# 5575-GNVDE        one year               no               mailed check
# 3668-QPYBK  month-to-month              yes               mailed check
# 7795-CFOCW        one year               no  bank transfer (automatic)
# 9237-HQITU  month-to-month              yes           electronic check
#
#             MonthlyCharges  TotalCharges  churn InternetService  \
# customerID
# 7590-VHVEG           29.85         29.85    0.0             NaN
# 5575-GNVDE           56.95       1889.50    0.0             NaN
# 3668-QPYBK           53.85        108.15    1.0             NaN
# 7795-CFOCW           42.30       1840.75    0.0             NaN
# 9237-HQITU           70.70        151.65    1.0             NaN
#
#            OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# customerID
# ...

# %%
# Colocar las columnas con valores nulos de internet en una variable llamada internet_service_cols
internet_service_cols = ['InternetService', 'OnlineSecurity', 'OnlineBackup',
                         'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

# LLenar valores nulos del df internet con "No"
for col in internet_service_cols:
    df_complete_outer[col].fillna('No', inplace=True)

# %%
# Verificar valores nulos o faltantes del df complete outer
df_complete_outer['MultipleLines'].fillna('No', inplace=True)
df_complete_outer.isna().sum().sort_values(ascending=False)
# Out:
# Type                5517
# PaymentMethod       5517
# MonthlyCharges      5517
# TotalCharges        5517
# churn               5517
# Dependents          5517
# Partner             5517
# SeniorCitizen       5517
# PaperlessBilling    5517
# gender              5517
# StreamingMovies        0
# DeviceProtection       0
# StreamingTV            0
# TechSupport            0
# OnlineBackup           0
# OnlineSecurity         0
# InternetService        0
# MultipleLines          0
# dtype: int64

# %%
# Eliminar filas donde todas esas columnas estén vacías
columnas_con_na = [
    'Type', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'churn',
    'Dependents', 'Partner', 'SeniorCitizen', 'PaperlessBilling', 'gender'
]

df_complete_outer = df_complete_outer.dropna(subset=columnas_con_na, how='all')

# %%
# Suma de valores nulos
print(df_complete_outer.isna().sum().sum())
# Out:
# 0

# %%
# Identificar los tipos de variables, categorica,numerica
cat_cols = df_complete_outer.select_dtypes(include=['object', 'category']).columns.tolist()
num_cols = df_complete_outer.select_dtypes(include=['int64', 'float64']).columns.tolist()

print("Categorical columns: 📓", cat_cols)
print("Numerical columns:📊", num_cols)
# Out:
# Categorical columns: 📓 ['Type', 'PaperlessBilling', 'PaymentMethod', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'gender', 'Partner', 'Dependents', 'MultipleLines']
# Numerical columns:📊 ['MonthlyCharges', 'TotalCharges', 'churn', 'SeniorCitizen']

# %%
#Graficar solo con la los datos de churn
g = sns.pairplot(df_complete_outer, hue='churn', kind='scatter', diag_kind='hist', plot_kws={'alpha': 0.5}, palette= ['skyblue', 'salmon'])
g.fig.set_size_inches(10, 10)
plt.show()

# %%
# Visualizacion de histograma para ver la comparativa entre clientes activos y cancelados.
# Estilo visual
sns.set(style="whitegrid")

# Crear gráfico de barras
plt.figure(figsize=(7, 4))
sns.countplot(data=df_complete_outer, x='churn', palette=['skyblue', 'salmon'])

# Personalizar etiquetas
plt.xticks([0, 1], ['Activos (0)', 'Cancelados (1)'])
plt.title('Comparativa entre clientes: Activos vs Cancelados')
plt.xlabel('Estado del Cliente')
plt.ylabel('Cantidad')
plt.tight_layout()
plt.show()

# %%
# Calculo del porcentaje del total entre los activos y los cancelados

# Contar clientes por clase de churn
churn_counts = df_complete_outer['churn'].value_counts()
total = churn_counts.sum()

# Calcular porcentajes
churn_percentages = churn_counts / total * 100

# Mostrar resultados
print("Porcentajes de clientes:")
print(f"✔️ Activos (churn = 0): {churn_percentages[0]:.2f}%")
print(f"❌ Cancelaron (churn = 1): {churn_percentages[1]:.2f}%")
# Out:
# Porcentajes de clientes:
# ✔️ Activos (churn = 0): 73.46%
# ❌ Cancelaron (churn = 1): 26.54%

# %%
# Gráfica de pastel
plt.figure(figsize=(6, 6))
plt.pie(
    churn_percentages,
    labels=['Activos', 'Cancelaron'],
    autopct='%1.1f%%',
    startangle=140,
    colors=['skyblue', 'salmon']
)
plt.title('Distribución de Clientes por Churn')
plt.axis('equal')
plt.show()

# %% [markdown]
# #### **Ya con los graficos y con la separacion de las columnas categoricas y numericas, asi como la transformacion de los datos entre 1 y 0 de los clientes que aun estan activos y los que ya cancelaron, vemos una notable diferencia entre los activos y los cancelados aun que es preocupante que cerca de un 1/3 del total de clientes a cancelado la suscripcion.**
# #### **Por lo que procederemos a la creacion de diferentes algoritmos de Maching Learning para ayudarnos a predecir las diferentes alternativas, para mejorar los clientes activos**

# %% [markdown]
# ## **4.-Correlaciones**

# %%
# Codificar las variables categóricas para evitar la multicolinealidad (elimina la primera categoría de cada columna)
df_encoded = pd.get_dummies(df_complete_outer, columns=cat_cols, drop_first=True)

# %%
# Matriz de correlaciones # Matriz de correlación solo con variables numéricas
corr_matrix = df_encoded.corr()
# Visualizar como mapa de calor
plt.figure(figsize=(12, 12))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=False, fmt='.2f', square=True, linewidths=0.5)
plt.title("Matriz de correlación")

plt.show()

# %% [markdown]
# 🎨 Interpretación de los colores
# Color	Valor de correlación	Significado:
#
# 🔴 Rojo oscuro	+1	Correlación positiva perfecta
# 🟠 Rojizo claro	~ +0.5	Correlación positiva moderada
# ⚪ Blanco / gris claro	0	Sin correlación
# 🔵 Azul claro	~ -0.5	Correlación negativa moderada
# 🔵 Azul oscuro	-1	Correlación negativa perfecta

# %% [markdown]
# ##### **churn y sus correlaciones más destacadas:**
#
# La columna/índice churn muestra correlaciones relativamente fuertes (aunque no extremas) con:
#
# InternetService_fiber optic → correlación positiva (más cancelaciones).
#
# OnlineSecurity_no, TechSupport_no → también positivas.
#
# PaymentMethod_electronic check → positiva.
#
# Contract_Type_one year y two year → correlaciones negativas (los clientes con contratos largos tienden a no cancelar).
#
# PaperlessBilling_yes → correlación positiva.
#
# MonthlyCharges y TotalCharges:
#
# Alta correlación entre sí (esperada).
#
# MonthlyCharges está algo correlacionada positivamente con churn.
#
# TotalCharges está negativamente correlacionada con churn (clientes que han pagado más en total tienden a quedarse).
#
# Servicios (como OnlineSecurity, TechSupport, StreamingTV) tienen relaciones visibles con churn.
#
# En general, la falta de servicios (_no) se asocia con más cancelaciones.

# %%
# ver cómo se distribuye MonthlyCharges según churn
sns.boxplot(data=df_encoded, x='churn', y='MonthlyCharges')
plt.title("Distribución de MonthlyCharges según churn")
plt.show()

# %%
# Filtramos solo columnas numéricas
numericas = df_encoded[['MonthlyCharges', 'churn']]

#Correlación Pearson
corr_pearson = numericas.corr(method='pearson')
print("Correlación Pearson entre variables numéricas:")
print(corr_pearson['churn'].sort_values(ascending=False))
# Out:
# Correlación Pearson entre variables numéricas:
# churn             1.000000
# MonthlyCharges    0.193356
# Name: churn, dtype: float64

# %% [markdown]
# 1.0: corresponde a la autocorrelación de churn consigo misma.
#
# 0.193: indica una correlación positiva débil entre MonthlyCharges y la cancelación. Es decir, a mayor cargo mensual, mayor probabilidad de que el cliente cancele.

# %%
# Seleccionamos todas las columnas numéricas automáticamente
numericas = df_encoded.select_dtypes(include=['int64', 'float64'])

# Correlación con churn
corr_pearson = numericas.corr(method='pearson')
print("Correlación Pearson con churn:")
print(corr_pearson['churn'].drop('churn').sort_values(key=abs, ascending=False).head(10))
# Out:
# Correlación Pearson con churn:
# TotalCharges     -0.198324
# MonthlyCharges    0.193356
# SeniorCitizen     0.150889
# Name: churn, dtype: float64

# %%
# Top 10 correlaciones absolutas con churn
top_corr = corr_pearson['churn'].drop('churn').sort_values(key=abs, ascending=False).head(10)

# Barplot
top_corr.plot(kind='barh', color='skyblue')
plt.title("Top 10 correlaciones con churn (Pearson)")
plt.xlabel("Coeficiente de correlación")
plt.gca().invert_yaxis()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Agrupar MonthlyCharges en rangos
df_encoded['MonthlyCharges_bins'] = pd.cut(df_encoded['MonthlyCharges'], bins=5)

# Crear tabla de frecuencias
tabla_frecuencia = pd.crosstab(df_encoded['churn'], df_encoded['MonthlyCharges_bins'])

# Visualizar como mapa de calor
plt.figure(figsize=(12, 5))
sns.heatmap(tabla_frecuencia, cmap='coolwarm', annot=True, fmt='d', linewidths=0.5, square=False)
plt.title("Frecuencia de churn por rango de Deuda Mensual de los Clientes")
plt.xlabel("Cargos mensuales en dolares")
plt.ylabel("Churn")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Interpretacion de la grafica**
# ##### **Rango más seguro:**
#
# (18.15, 38.35]: Tiene la mayor cantidad de clientes que no cancelan (churn = 0) con 1,592 casos y relativamente pocos que sí cancelan (205).
#
# Esto sugiere que los clientes con cargos mensuales bajos son menos propensos a cancelar.
#
# ##### **Mayor riesgo de cancelación:**
#
# En el rango (78.55, 98.65], el número de cancelaciones (675) es más alto en proporción que en los rangos más bajos.
#
# Aunque también hay muchos clientes que no cancelan en ese grupo (1,151), la tasa de cancelación relativa aumenta con el cargo mensual.
#
# ##### **Tendencia general:**
#
# A medida que aumenta MonthlyCharges, el número de clientes que cancelan también aumenta.
#
# Esto refuerza la correlación positiva moderada que encontraste antes entre MonthlyCharges y churn.

# %% [markdown]
# #### **Con los datos obtenidos vemos que no hay algun feacture que este muy relacionada con churn, aun que la mas correlacionada es con la columna de MonthlyCharges por lo que se deduce que a mayor cargo mensual, mayor es la cancelacion de la suscripcion, por lo que vamos a proceder con el modelado de los algoritmos de maching learning.**

# %% [markdown]
# ## **5.-Modelado**

# %%
# Codificar las variables categóricas para evitar la multicolinealidad (elimina la primera categoría de cada columna)
df_encoded = pd.get_dummies(df_complete_outer, columns=cat_cols, drop_first=True)

# %%
# Dividir las variables objetivo
target = df_encoded['churn']
features = df_encoded.drop(columns='churn')

# %%
# División en conjunto de entrenamiento y validación
features_train, features_valid, target_train, target_valid = train_test_split(
    features, target, test_size=0.30, random_state=42)

# %% [markdown]
# ##### **Modelo de arbol de desicion:**

# %%
# Utiliza los datos transformados para entrenar un árbol de decisión.

# Crear el modelo de árbol de decisión con control el sobreajuste ajustando hiperparámetros:
model = DecisionTreeClassifier(max_depth=5, min_samples_leaf=10, random_state=42)

# Entrenar el modelo
model.fit(features_train, target_train)

# Predecir en el conjunto de validación
predicted_valid = model.predict(features_valid)

# Desicion Tree
print(f'🌳✅Desicion Tree Accuracy: {accuracy_score(target_valid, predicted_valid):.2f}')
print(f'🌳✅Desicion Tree Precision: {precision_score(target_valid, predicted_valid):.2f}')
print(f'🌳✅Desicion Tree Recall: {recall_score(target_valid, predicted_valid):.2f}')
print(f'🌳✅Desicion Tree F1-score: {f1_score(target_valid, predicted_valid):.2f}')
# Out:
# 🌳✅Desicion Tree Accuracy: 0.78
# 🌳✅Desicion Tree Precision: 0.63
# 🌳✅Desicion Tree Recall: 0.48
# 🌳✅Desicion Tree F1-score: 0.54

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - El objetivo del proyecto menciona aplicar *algoritmos de machine learning e hiperparámetros para mejorar la estancia de los clientes*, pero se utilizó una variable objetivo (`contract_duration_days`) que representa duración histórica, no predicción futura de churn. Sería valioso replantear la variable objetivo hacia algo más directamente conectado al abandono del cliente (por ejemplo, crear una variable binaria de churn basada en `EndDate`). Ajustar esto hará que tus modelos estén más alineados con el objetivo del negocio. ¡Confío plenamente en que puedes ajustarlo y llevar el análisis aún más lejos!
#
# </div>

# %% [markdown]
# # Comentario General del Revisor.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# <b>A resolver</b> ❗ - Gracias por el esfuerzo demostrado en la entrega. Has trabajado con múltiples fuentes de datos, aplicado transformaciones correctas y entrenado diversos modelos, lo que evidencia dedicación y conocimiento técnico. Sin embargo, debemos detenernos en un punto crítico que afecta la validez del proyecto:
#
# ---
#
# ### ❌ Motivo de rechazo del proyecto (por ahora)
#
# El objetivo del proyecto consiste en **predecir si un cliente abandonará o no la empresa**, lo cual es un problema de **clasificación binaria** (churn: sí/no). Sin embargo, el enfoque implementado fue el de **regresión para predecir la duración del contrato**, lo que no cumple con el objetivo central del proyecto final.
#
# Este error conceptual en la elección de la variable objetivo y del tipo de modelo utilizado hace que **los resultados no sean válidos para tomar decisiones respecto al abandono de clientes**.
#
# ---
#
# ### 🛠️ Qué debes corregir
#
# Por ahora, **no necesitas rehacer todo el proyecto**. Basta con:
#
# * Replantear la variable objetivo: por ejemplo, crear una variable `is_churn` (1 si hay fecha de fin de contrato, 0 si sigue activo).
# * Usar modelos de **clasificación** como `LogisticRegression`, `RandomForestClassifier`, `CatBoostClassifier`, etc.
# * Evaluar el rendimiento con métricas adecuadas: `AUC`, `Recall`, `F1`, etc.
# * Dejar de usar `contract_duration_days` como objetivo, ya que no permite resolver la pregunta de negocio planteada.
#
# ---
#
# ### ✅ Aspectos que has hecho bien
#
# * Limpieza adecuada de datos y tratamiento de tipos.
# * Integración correcta de fuentes con claves comunes (`customerID`).
# * Aplicación de codificación y escalado correctamente.
# * Evaluación de modelos con métricas cuantitativas.
#
# ---
#
# Una vez hayas realizado el ajuste conceptual y técnico hacia un problema de clasificación, podrás entregar nuevamente tu notebook para su revisión. Estoy seguro de que con esta corrección, tu proyecto podrá ser aprobado.
#
# </div>

# %%
from sklearn.tree import plot_tree

#Visualizacion del arbol 
plt.figure(figsize=(15, 10))
plot_tree(model, feature_names=features.columns, class_names=['No', 'Yes'], filled=True, max_depth=3)
plt.title("Árbol de Decisión (primeros niveles)")
plt.show()

# %% [markdown]
# ##### **Modelo de bosque de desicion:**

# %%
# Lista de estimadores a probar
estimators = [10, 50, 100, 200, 500]

print("n_estimators | RMSE | ROC AUC |    Accuracy   |   Precision  |   Recall  |   F1-score")
print("---------------------------------------------")

# Probar diferentes valores de n_estimators
for n in estimators:
    model = RandomForestClassifier(n_estimators=n, random_state=42)
    model.fit(features_train, target_train)

    predicted_valid = model.predict(features_valid)
    predicted_proba = model.predict_proba(features_valid)[:, 1]

    rmse = mean_squared_error(target_valid, predicted_valid, squared=False)
    roc_auc = roc_auc_score(target_valid, predicted_proba)

    accuracy = accuracy_score(target_valid, predicted_valid)
    precision = precision_score(target_valid, predicted_valid)
    recall = recall_score(target_valid, predicted_valid)
    f1 = f1_score(target_valid, predicted_valid)

    print(f"{n:<12} | {rmse:.2f}|{roc_auc:.2f} |{accuracy:.2f} | {precision:.2f}  | {recall:.2f}  | {f1:.2f}")
# Out:
# n_estimators | RMSE | ROC AUC |    Accuracy   |   Precision  |   Recall  |   F1-score
# ---------------------------------------------
# 10           | 0.47|0.79 |0.78 | 0.63  | 0.44  | 0.52
# 50           | 0.46|0.81 |0.79 | 0.65  | 0.46  | 0.54

# %% [markdown]
# **El mejor modelo parece ser con n_estimators = 200, ya que tiene:**
#
# Mejor F1-score (0.56)
#
# Mejor precisión (0.67) con recall razonable

# %%
#Entrenar modelo solo para 200 estimaciones o muestras debido a que tiene los mejores resultados
model = RandomForestClassifier(n_estimators=200, random_state=42)
model.fit(features_train, target_train)

predicted_valid = model.predict(features_valid)
predicted_proba = model.predict_proba(features_valid)[:, 1]

accuracy = accuracy_score(target_valid, predicted_valid)
precision = precision_score(target_valid, predicted_valid)
recall = recall_score(target_valid, predicted_valid)
f1 = f1_score(target_valid, predicted_valid)

# Evaluar el modelo
print(f'🌲🌲✅RandomForestClassifier Accuracy: {accuracy_score(target_valid, predicted_valid):.2f}')
print(f'🌲🌲✅RandomForestClassifier Precision: {precision_score(target_valid, predicted_valid):.2f}')
print(f'🌲🌲✅RandomForestClassifier Recall: {recall_score(target_valid, predicted_valid):.2f}')
print(f'🌲🌲✅RandomForestClassifier F1-score: {f1_score(target_valid, predicted_valid):.2f}')

# %%
#Graficar la curva roc
from sklearn.metrics import roc_curve, roc_auc_score
# Entrenar el modelo con 200 árboles
model = RandomForestClassifier(n_estimators=200, random_state=42)
model.fit(features_train, target_train)

# Obtener probabilidades para la clase positiva en el conjunto de validación
y_proba = model.predict_proba(features_valid)[:, 1]

# Calcular los valores de la curva ROC
fpr, tpr, thresholds = roc_curve(target_valid, y_proba)
roc_auc = roc_auc_score(target_valid, y_proba)

# Graficar
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC - Random Forest (n=200)')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Un AUC de 0.83** indica que el modelo tiene una muy buena capacidad para distinguir entre clases. En términos prácticos:
#
# 📈 Área bajo la curva **(AUC = 0.83)** significa que, si seleccionas al azar un cliente que canceló y uno que no, el modelo tiene un 83% de probabilidad de asignar una probabilidad más alta al cliente que sí canceló.
#
# 📊 La curva se acerca bastante al vértice superior izquierdo, lo cual indica una buena tasa de verdaderos positivos con bajo falso positivo.

# %% [markdown]
# ##### **Modelo de regresion logistica:**

# %%
# Entrenar Logistic Regression
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000, solver='liblinear', random_state=42)
model.fit(features_train, target_train)
# Predecir etiquetas y probabilidades en el conjunto de validación
predicted_valid = model.predict(features_valid)
proba_valid = model.predict_proba(features_valid)[:, 1]

# Evaluación del modelo
accuracy = accuracy_score(target_valid, predicted_valid)
precision = precision_score(target_valid, predicted_valid)
recall = recall_score(target_valid, predicted_valid)
f1 = f1_score(target_valid, predicted_valid)
roc_auc = roc_auc_score(target_valid, proba_valid)

# Mostrar métricas
print(f"📈✅LogisticRegression Accuracy:  {accuracy:.2f}")
print(f"📈✅LogisticRegression Precision: {precision:.2f}")
print(f"📈✅LogisticRegression Recall:    {recall:.2f}")
print(f"📈✅LogisticRegression F1-score:  {f1:.2f}")
print(f"📈✅LogisticRegression ROC AUC:   {roc_auc:.2f}")


# Curva ROC
lr_fpr, lr_tpr, _ = roc_curve(target_valid, proba_valid)
lr_auc = roc_auc

# Graficar curva ROC
plt.figure(figsize=(8, 6))
plt.plot(lr_fpr, lr_tpr, label=f'📈 Logistic Regression (AUC = {lr_auc:.2f})', color='green')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Comparación de curvas ROC')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **6.-comparar las metricas de los 3 modelos ejecutados.**

# %%
# Desicion Tree
print(f'🌳✅Desicion Tree Accuracy: {accuracy_score(target_valid, predicted_valid):.2f}')
print(f'🌳✅Desicion Tree Precision: {precision_score(target_valid, predicted_valid):.2f}')
print(f'🌳✅Desicion Tree Recall: {recall_score(target_valid, predicted_valid):.2f}')
print(f'🌳✅Desicion Tree F1-score: {f1_score(target_valid, predicted_valid):.2f}')

# RandomForestClassifier
print(f'🌲🌲✅RandomForestClassifier Accuracy: {accuracy_score(target_valid, predicted_valid):.2f}')
print(f'🌲🌲✅RandomForestClassifier Precision: {precision_score(target_valid, predicted_valid):.2f}')
print(f'🌲🌲✅RandomForestClassifier Recall: {recall_score(target_valid, predicted_valid):.2f}')
print(f'🌲🌲✅RandomForestClassifier F1-score: {f1_score(target_valid, predicted_valid):.2f}')

# LogisticRegression
print(f"📈✅LogisticRegression Accuracy:  {accuracy:.2f}")
print(f"📈✅LogisticRegression Precision: {precision:.2f}")
print(f"📈✅LogisticRegression Recall:    {recall:.2f}")
print(f"📈✅LogisticRegression F1-score:  {f1:.2f}")
print(f"📈✅LogisticRegression ROC AUC:   {roc_auc:.2f}")

# %% [markdown]
# ### **7.-CONCLUCION:**
# #### Aunque todos los modelos tienen métricas idénticas en Accuracy, Precision, Recall y F1-score, la **regresión logística sobresale en la métrica de ROC AUC (0.85)**, lo que indica que tiene mejor capacidad discriminativa (diferencia entre clases positivas y negativas) frente a los árboles.
#
# #### **Como recomendaciones:**
# #### **1.-Usar la regresión logística para producción, ya que no solo es más interpretable para el equipo de negocio, sino que ofrece mayor confianza en las probabilidades de cancelación predichas.**
#
# #### **2.-Identificar clientes con alta probabilidad de cancelación usando el modelo y lanzar campañas específicas de retención (descuentos, atención personalizada, renovaciones anticipadas).**
#
# #### **3.-Monitorear las métricas periódicamente y actualizar el modelo con datos nuevos para asegurar su vigencia y efectividad.**

# %% [markdown]
# # Comentario General del Revisor
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Proyecto aprobado! Has logrado desarrollar un análisis completo de abandono de clientes que abarca desde la limpieza e integración de datos hasta la comparación de varios modelos de clasificación. La lógica de trabajo está bien fundamentada y has aplicado herramientas robustas tanto de visualización como de modelado predictivo. La estructura del proyecto denota un gran compromiso y esfuerzo por resolver un problema real de negocio.
#
# ### Puntos Positivos:
#
# * **Transformación correcta de la variable objetivo:** Usaste apropiadamente el campo `EndDate` para derivar la variable `churn`, lo cual está bien alineado con el objetivo del proyecto.
# * **Aplicación de múltiples modelos supervisados:** Probaste modelos como árbol de decisión, random forest y regresión logística, mostrando madurez analítica.
# * **Evaluación de métricas clave:** Consideraste Accuracy, Recall, Precision, F1 y AUC para elegir el mejor modelo, lo cual es esencial para una buena toma de decisiones.
# * **Interpretabilidad:** Ofreces conclusiones claras que conectan los resultados técnicos con acciones prácticas como campañas de retención.
#
# ### Áreas de Mejora para la Próxima Entrega:
#
# * **Separación por fases:** Este entregable correspondía solo al plan de proyecto. Para continuar, se te habilitará una nueva entrega donde deberás subir el código y los resultados en un notebook limpio y estructurado.
# * **Limpieza visual:** Te recomendamos mejorar la estética y legibilidad de los gráficos, en especial la matriz de correlación. Usa anotaciones solo cuando sea necesario y evita sobrecargar la visualización.
# * **Tipos de correlación:** Investiga la correlación biserial puntual (*point-biserial correlation*), que es más apropiada cuando relacionas variables numéricas con binarias como `churn`, a diferencia del coeficiente de Pearson.
# * **Conclusión final en markdown:** Mejora la presentación de la sección de conclusiones usando formato Markdown, separando ideas en subtítulos y resaltando recomendaciones clave.
#
# Con estos ajustes finales, tu análisis será no solo sólido, sino también comunicativamente claro y profesional. ¡Sigue adelante, estás muy cerca de completar este gran proyecto!
#
# </div>

# %% [markdown]
# # **NOTA:**
#
# Ya despues se la revicion y agradezco tus comentarios Hesus Garcia, mejore mi proyecto, tomando en cuenta los puntos que me diste, creo ya mejoro bastante este proyecto, asi mismo implemente metricas para evaluar las correlaciones entre chur y la columna de adeudo mensual, ya que es la que mejor correlacion tiene con respecto a los clientes que cancelan, llegando a la conclucion, de que los clientes entre mas deuda tengan, mas fasilmente cancelaran la suscripcion.
#
# #### **Te agradezco mucho el apoyo Hesus y si eres la unica persona que conozco que empieza con H el jesus.**
# #### **Saludos.**
